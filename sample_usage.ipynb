# %%
import time
import matplotlib.pyplot as plt
from kaolin_render import render_glb_with_hammersley

# %%
glb_path = "/home/ubuntu/lacd/acid/data/train_data/behavior1k/behavior1k_glbs/apple__obixxh.glb"

images, depths = render_glb_with_hammersley(glb_path, num_views=10, res=512)
# Out:
# /home/ubuntu/lacd/env/partfield-env/lib/python3.10/site-packages/kaolin/io/gltf.py:285: UserWarning: The given buffer is not writable, and PyTorch does not support non-writable tensors. This means you can write to the underlying (supposedly non-writable) buffer using the tensor. You may want to copy the buffer to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:1544.)
#   output = torch.frombuffer(
# /home/ubuntu/kaolin-easy-render-patch/kaolin_render.py:383: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   amplitude=torch.tensor(amplitude, device=camera.device),
# ...

# %%
plt.figure(figsize=(15, 5))
for i, img in enumerate(images):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img)
    plt.axis('off')

# %%
plt.figure(figsize=(15, 5))
for i, img in enumerate(depths):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.axis('off')
